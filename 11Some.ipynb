# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
def input_fn():
    dataset = tf.contrib.data.make_csv_dataset(
    "AllFiredAreFiredRnD2.6.csv", batch_size=10, num_epochs=1000)
    return dataset


#tf.estimator.Estimator(model_fn=).train(input_fn=input_fn)
#model = tf.estimator.LinearRegressor(feature_columns=feat_cols)

# %%
data = pd.read_csv('AllFiredAreFiredRnD2.6.csv', sep=';', encoding='latin-1', low_memory=False)
data.head()
# Out:
#       Y   M  EmplId                   FullNameEng     Status  \
# 0  2018   2    8453       Ababilov Oleg Igorevich  Terminate
# 1  2018   1    8453       Ababilov Oleg Igorevich     Active
# 2  2018  10   10454  Abdrashitov Zagir Ramirovich     Active
# 3  2018   9   10454  Abdrashitov Zagir Ramirovich     Active
# 4  2018   8   10454  Abdrashitov Zagir Ramirovich     Active
#
#    VacationDaysCollected  TerminationFact  Terminationdate TerminationReason  \
# 0                     13                1            43157        Relocation
# 1                     13                1                0              None
# 2                      0                0                0              None
# 3                      0                0                0              None
# 4                      0                0                0              None
#
#   Termreasoncategory        ...         Talent   CR Averageageintheteam  \
# ...

# %%
data.columns
# Out:
# Index(['Y', 'M', 'EmplId', 'FullNameEng', 'Status', 'VacationDaysCollected',
#        'TerminationFact', 'Terminationdate', 'TerminationReason',
#        'Termreasoncategory', 'TopDept', 'DepFull', 'StaffCountry', 'Location',
#        'HomeOffice', 'StaffTypeName', 'HC', 'Topdptreorg', 'Division',
#        'Region', 'Hiredate', 'LoS', 'DaysOfServ', 'DoB', 'Age', 'Gender',
#        'Grade', 'Manager', 'SPAN', 'Performance', 'Talent', 'CR',
#        'Averageageintheteam', 'AverageageintheteamDays', 'Agediffwithteam1000',
#        'numberofteammates', 'Managersage', 'AgediffwithManager',
#        'Differentlocationwithmanager', 'Overtimehourscumul'],
#       dtype='object')

# %%
# cols_to_norm = ['userid','gradeto']
# data[cols_to_norm] = data[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max() - x.min() ))

# %%
'''
feat_userid = tf.feature_column.numeric_column('userid')
feat_gradeto = tf.feature_column.numeric_column('gradeto')
feat_subfamilynameto = tf.feature_column.categorical_column_with_hash_bucket('subfamilynameto',hash_bucket_size=110)
feat_corporatetitleto = tf.feature_column.categorical_column_with_hash_bucket('corporatetitleto',hash_bucket_size=2050)
feat_eventto = tf.feature_column.categorical_column_with_hash_bucket('eventto',hash_bucket_size=25)
feat_fullpathto = tf.feature_column.categorical_column_with_hash_bucket('fullpathto',hash_bucket_size=2200)
feat_deptto = tf.feature_column.categorical_column_with_hash_bucket('deptto',hash_bucket_size=1450)
feat_topdeptto = tf.feature_column.categorical_column_with_hash_bucket('topdeptto',hash_bucket_size=150)
feat_regionto = tf.feature_column.categorical_column_with_hash_bucket('regionto',hash_bucket_size=20)
#feat_fired = tf.feature_column.numeric_column('fired')

feat_cols = [feat_userid,feat_gradeto,feat_subfamilynameto,feat_corporatetitleto,feat_eventto,feat_fullpathto,feat_deptto,feat_topdeptto,feat_regionto,]
'''
# Out:
# "\nfeat_userid = tf.feature_column.numeric_column('userid')\nfeat_gradeto = tf.feature_column.numeric_column('gradeto')\nfeat_subfamilynameto = tf.feature_column.categorical_column_with_hash_bucket('subfamilynameto',hash_bucket_size=110)\nfeat_corporatetitleto = tf.feature_column.categorical_column_with_hash_bucket('corporatetitleto',hash_bucket_size=2050)\nfeat_eventto = tf.feature_column.categorical_column_with_hash_bucket('eventto',hash_bucket_size=25)\nfeat_fullpathto = tf.feature_column.categorical_column_with_hash_bucket('fullpathto',hash_bucket_size=2200)\nfeat_deptto = tf.feature_column.categorical_column_with_hash_bucket('deptto',hash_bucket_size=1450)\nfeat_topdeptto = tf.feature_column.categorical_column_with_hash_bucket('topdeptto',hash_bucket_size=150)\nfeat_regionto = tf.feature_column.categorical_column_with_hash_bucket('regionto',hash_bucket_size=20)\n#feat_fired = tf.feature_column.numeric_column('fired')\n\nfeat_cols = [feat_userid,feat_gradeto,feat_subfamilynameto,
# ...

# %%
#feat_TerminationFact = tf.feature_column.numeric_column('TerminationFact')
#feat_Terminationdate = tf.feature_column.numeric_column('Terminationdate')
#feat_TerminationReason = tf.feature_column.categorical_column_with_hash_bucket('TerminationReason',hash_bucket_size=30)
#feat_TermReasonCategory = tf.feature_column.categorical_column_with_hash_bucket('Termreasoncategory',hash_bucket_size=30)
#feat_Status = tf.feature_column.categorical_column_with_hash_bucket('Status',hash_bucket_size=3)

feat_Y = tf.feature_column.numeric_column('Y')
feat_M = tf.feature_column.numeric_column('M')
feat_EmplId = tf.feature_column.numeric_column('EmplId')
feat_FullNameEng = tf.feature_column.categorical_column_with_hash_bucket('FullNameEng',hash_bucket_size=2300)
feat_VacationDaysCollected = tf.feature_column.numeric_column('VacationDaysCollected')
feat_TopDept = tf.feature_column.categorical_column_with_hash_bucket('TopDept',hash_bucket_size=30)
feat_DepFull = tf.feature_column.categorical_column_with_hash_bucket('DepFull',hash_bucket_size=470)
feat_StaffCountry = tf.feature_column.categorical_column_with_hash_bucket('StaffCountry',hash_bucket_size=50)
feat_Location = tf.feature_column.categorical_column_with_hash_bucket('Location',hash_bucket_size=65)
feat_HomeOffice = tf.feature_column.numeric_column('HomeOffice')
feat_StaffTypeName = tf.feature_column.categorical_column_with_hash_bucket('StaffTypeName',hash_bucket_size=3)
feat_HC = tf.feature_column.numeric_column('HC')
feat_TopDptReorg = tf.feature_column.categorical_column_with_hash_bucket('Topdptreorg',hash_bucket_size=35)
feat_Division = tf.feature_column.categorical_column_with_hash_bucket('Division',hash_bucket_size=3)
feat_Region = tf.feature_column.categorical_column_with_hash_bucket('Region',hash_bucket_size=15)
feat_Hiredate = tf.feature_column.numeric_column('Hiredate')
feat_LoS = tf.feature_column.numeric_column('LoS')
feat_DoB = tf.feature_column.numeric_column('DoB')
feat_Age = tf.feature_column.numeric_column('Age')
feat_Gender = tf.feature_column.categorical_column_with_hash_bucket('Gender',hash_bucket_size=3)
feat_Grade = tf.feature_column.numeric_column('Grade')
feat_Manager = tf.feature_column.numeric_column('Manager')
feat_SPAN = tf.feature_column.numeric_column('SPAN')
feat_Performance = tf.feature_column.numeric_column('Performance')
feat_Talent = tf.feature_column.numeric_column('Talent')
feat_CR = tf.feature_column.numeric_column('CR')
feat_numberofteammates = tf.feature_column.numeric_column('numberofteammates')
feat_Managerage = tf.feature_column.numeric_column('Managersage')
feat_Differentlocationwithmanager = tf.feature_column.numeric_column('Differentlocationwithmanager')
feat_Overtimehourscumul = tf.feature_column.numeric_column('Overtimehourscumul')
feat_Overtimehourspermonth = tf.feature_column.numeric_column('Overtimehourspermonth')

feat_Agediffwithteam = tf.feature_column.numeric_column('Agediffwithteam1000')
feat_AgediffwithManager = tf.feature_column.numeric_column('AgediffwithManager')
feat_Averageage = tf.feature_column.numeric_column('Averageageintheteam')


feat_cols = [feat_Y,feat_M,feat_EmplId,feat_FullNameEng,
             feat_VacationDaysCollected,feat_TopDept,feat_DepFull,
             feat_StaffCountry,feat_Location,feat_HomeOffice,
             feat_StaffTypeName,feat_HC,feat_TopDptReorg,feat_Division,
             feat_Region,feat_Hiredate,feat_LoS,feat_DoB,feat_Age,
             feat_Gender,feat_Grade,feat_Manager,feat_SPAN,
             feat_Performance,feat_Talent,feat_CR,
             feat_numberofteammates,feat_Managerage,
             feat_Differentlocationwithmanager,feat_Agediffwithteam,feat_AgediffwithManager,feat_Averageage]

#feat_cols = [feat_Terminationdate,feat_TerminationReason,feat_TermReasonCategory,feat_Y,feat_M,feat_EmplId,feat_FullNameEng,feat_Status,feat_VacationDaysCollected,feat_TopDept,feat_DepFull,feat_StaffCountry,feat_Location,feat_HomeOffice,feat_StaffTypeName,feat_HC,feat_TopDptReorg,feat_Division,feat_Region,feat_Hiredate,feat_LoS,feat_DoB,feat_Age,feat_Gender,feat_Grade,feat_Manager,feat_SPAN,feat_Performance,feat_Talent,feat_CR,feat_Averageage,feat_Agediffwithteam,feat_numberofteammates,feat_Managerage,feat_AgediffwithManager,feat_Differentlocationwithmanager,feat_Overtimehourscumul,feat_Overtimehourspermonth,]
#feat_cols = [feat_Y,feat_M,feat_EmplId,feat_FullNameEng,feat_Status,feat_VacationDaysCollected,feat_Terminationdate,feat_TerminationReason,feat_TermReasonCategory,feat_TopDept,feat_DepFull,feat_StaffCountry,feat_Location,feat_HomeOffice,feat_StaffTypeName,feat_HC,feat_TopDptReorg,feat_Division,feat_Region,feat_Hiredate]

# %%
#x_data = data.drop('TerminationFact',axis=1)
x_data = data
labels = data['TerminationFact']

x_data.head()
# Out:
#       Y   M  EmplId                   FullNameEng     Status  \
# 0  2018   2    8453       Ababilov Oleg Igorevich  Terminate
# 1  2018   1    8453       Ababilov Oleg Igorevich     Active
# 2  2018  10   10454  Abdrashitov Zagir Ramirovich     Active
# 3  2018   9   10454  Abdrashitov Zagir Ramirovich     Active
# 4  2018   8   10454  Abdrashitov Zagir Ramirovich     Active
#
#    VacationDaysCollected  TerminationFact  Terminationdate TerminationReason  \
# 0                     13                1            43157        Relocation
# 1                     13                1                0              None
# 2                      0                0                0              None
# 3                      0                0                0              None
# 4                      0                0                0              None
#
#   Termreasoncategory        ...         Talent   CR Averageageintheteam  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data,labels, test_size=0.5, random_state=101)
X_train2, X_test2, y_train2, y_test2 = train_test_split(x_data,labels, test_size=0.99, random_state=101)


input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=100,num_epochs=10000,shuffle=False)
eval_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test,y=y_test,batch_size=10,num_epochs=1,shuffle=False)

model = tf.estimator.LinearRegressor(feature_columns=feat_cols)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Alex\AppData\Local\Temp\tmphh56pt41
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\Alex\\AppData\\Local\\Temp\\tmphh56pt41', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# ...

# %%
model.train(input_fn=input_func,steps=10000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Alex\AppData\Local\Temp\tmphh56pt41\model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 10000 into C:\Users\Alex\AppData\Local\Temp\tmphh56pt41\model.ckpt.
# INFO:tensorflow:loss = 8.781839, step = 10001
# INFO:tensorflow:global_step/sec: 131.068
# INFO:tensorflow:loss = 9.937371, step = 10101 (0.763 sec)
# INFO:tensorflow:global_step/sec: 213.335
# INFO:tensorflow:loss = 23.446146, step = 10201 (0.470 sec)
# INFO:tensorflow:global_step/sec: 208.89
# INFO:tensorflow:loss = 6.635171, step = 10301 (0.479 sec)
# INFO:tensorflow:global_step/sec: 225.827
# INFO:tensorflow:loss = 5.5845222, step = 10401 (0.442 sec)
# INFO:tensorflow:global_step/sec: 221.34
# ...

# %%
results = model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-20-14:54:46
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Alex\AppData\Local\Temp\tmphh56pt41\model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-20-14:54:48
# INFO:tensorflow:Saving dict for global step 20000: average_loss = 0.07852379, global_step = 20000, label/mean = 0.0773132, loss = 0.7846189, prediction/mean = 0.057990257
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 20000: C:\Users\Alex\AppData\Local\Temp\tmphh56pt41\model.ckpt-20000

# %%
results
# Out:
# {'average_loss': 0.07852379,
#  'label/mean': 0.0773132,
#  'loss': 0.7846189,
#  'prediction/mean': 0.057990257,
#  'global_step': 20000}

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test2,batch_size=10,num_epochs=1,shuffle=False)

# %%
predictions = model.predict(pred_input_func)

# %%
my_pred = list(predictions)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Alex\AppData\Local\Temp\tmphh56pt41\model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
my_pred
# Out:
# [{'predictions': array([0.17117454], dtype=float32)},
#  {'predictions': array([0.99027574], dtype=float32)},
#  {'predictions': array([-0.13242258], dtype=float32)},
#  {'predictions': array([-0.6092998], dtype=float32)},
#  {'predictions': array([-0.31414914], dtype=float32)},
#  {'predictions': array([-0.60569733], dtype=float32)},
#  {'predictions': array([-0.32058126], dtype=float32)},
#  {'predictions': array([0.02170984], dtype=float32)},
#  {'predictions': array([-0.03722604], dtype=float32)},
#  {'predictions': array([-0.05910141], dtype=float32)},
#  {'predictions': array([-0.06954505], dtype=float32)},
#  {'predictions': array([-0.03912211], dtype=float32)},
#  {'predictions': array([-0.14242141], dtype=float32)},
#  {'predictions': array([0.30943674], dtype=float32)},
#  {'predictions': array([-0.0212001], dtype=float32)},
#  {'predictions': array([-0.02138337], dtype=float32)},
#  {'predictions': array([0.01830748], dtype=float32)},
# ...

# %%
dfxtest = pd.DataFrame(X_test2)
dfxtest.to_csv("regressionclxtest27-all.csv")

X_test
# Out:
#           Y   M  EmplId                         FullNameEng  Status  \
# 5785   2018   3    8327      Katentsev Andrey Alexandrovich  Active
# 835    2018   3    8794             Baranov Artem Ivanovich  Active
# 13012  2018   7    7134        Savitsky Vitaly Mikhaylovich  Active
# 16484  2018   1     530          Volkova Natalya Victorovna  Active
# 9503   2018  10    9977                        Miyake Naomi  Active
# 8294   2018   5    1089        Liskin Alexander Victorovich  Active
# 13851  2018   4    7842  Shrubkovskaya Alexandra Vasilyevna  Active
# 8964   2018   9    5389           Martynov Pavel Sergeevich  Active
# 1175   2018   9    7838              Bentsa Inna Kirillovna  Active
# 14109  2018   3    4378        Sidyakin Pavel Alexandrovich  Active
# 11386  2018   6    9047         Pokrovsky Dmitry Sergeevich  Active
# 2394   2018   9    6294                        Creus Daniel  Active
# 14510  2018  10    8278      Smolnyakov Artem Vladimirovich  Active
# ...

# %%
for _ in my_pred:
    print(_)
    
dfpred = pd.DataFrame(my_pred)
dfpred.to_csv("regressionclpred27-all.csv")
# Out:
# {'predictions': array([0.17117454], dtype=float32)}
# {'predictions': array([0.99027574], dtype=float32)}
# {'predictions': array([-0.13242258], dtype=float32)}
# {'predictions': array([-0.6092998], dtype=float32)}
# {'predictions': array([-0.31414914], dtype=float32)}
# {'predictions': array([-0.60569733], dtype=float32)}
# {'predictions': array([-0.32058126], dtype=float32)}
# {'predictions': array([0.02170984], dtype=float32)}
# {'predictions': array([-0.03722604], dtype=float32)}
# {'predictions': array([-0.05910141], dtype=float32)}
# {'predictions': array([-0.06954505], dtype=float32)}
# {'predictions': array([-0.03912211], dtype=float32)}
# {'predictions': array([-0.14242141], dtype=float32)}
# {'predictions': array([0.30943674], dtype=float32)}
# {'predictions': array([-0.0212001], dtype=float32)}
# {'predictions': array([-0.02138337], dtype=float32)}
# {'predictions': array([0.01830748], dtype=float32)}
# {'predictions': array([0.01049911], dtype=float32)}
# ...
