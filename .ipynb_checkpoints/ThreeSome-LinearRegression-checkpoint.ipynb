# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
data = pd.read_csv('test.csv', sep=';')
data.head()
# Out:
#    userid  gradeto       subfamilynameto           corporatetitleto  \
# 0    1000       15     Product Marketing       VP Product Marketing
# 1   10000       10  Software Engineering           Senior Developer
# 2   10001       10  Software Engineering  Senior Research Developer
# 3   10002        7  Test Engineering R&D           Testing Engineer
# 4   10003        9  Software Engineering                  Developer
#
#        eventto  fired                 fullpathto  \
# 0  Data Change      0                    ProdMkt
# 1  Data Change      0          FutureTechSecPlat
# 2     Transfer      0  R&DPDOLinuxKICSNetwIndPDK
# 3  Data Change      0       R&DIDOIntDevPlatform
# 4  Data Change      0                      InIPA
#
#                              deptto   topdeptto regionto  agefake  classfake  \
# 0                 Product Marketing     ProdMkt   Russia       77          1
# 1       Secure Platform Development  FutureTech   Russia       77          1
# 2  KICS for Networks Industrial PDK         PDO   Russia       77          1
# 3              Platform Development         IDO   Russia       77          1
# 4                     Privacy Audit         InI   Russia       77          1
#
#   groupfake
# 0         A
# 1         A
# 2         A
# 3         A
# 4         A

# %%
data.columns
# Out:
# Index(['userid', 'gradeto', 'subfamilynameto', 'corporatetitleto', 'eventto',
#        'fired', 'fullpathto', 'deptto', 'topdeptto', 'regionto', 'agefake',
#        'classfake', 'groupfake'],
#       dtype='object')

# %%
# cols_to_norm = ['userid','gradeto']
# data[cols_to_norm] = data[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max() - x.min() ))

# %%
feat_userid = tf.feature_column.numeric_column('userid')
feat_gradeto = tf.feature_column.numeric_column('gradeto')
feat_subfamilynameto = tf.feature_column.categorical_column_with_hash_bucket('subfamilynameto',hash_bucket_size=110)
feat_corporatetitleto = tf.feature_column.categorical_column_with_hash_bucket('corporatetitleto',hash_bucket_size=2050)
feat_eventto = tf.feature_column.categorical_column_with_hash_bucket('eventto',hash_bucket_size=25)
feat_fullpathto = tf.feature_column.categorical_column_with_hash_bucket('fullpathto',hash_bucket_size=2200)
feat_deptto = tf.feature_column.categorical_column_with_hash_bucket('deptto',hash_bucket_size=1450)
feat_topdeptto = tf.feature_column.categorical_column_with_hash_bucket('topdeptto',hash_bucket_size=150)
feat_regionto = tf.feature_column.categorical_column_with_hash_bucket('regionto',hash_bucket_size=20)
#feat_fired = tf.feature_column.numeric_column('fired')

feat_cols = [feat_userid,feat_gradeto,feat_subfamilynameto,feat_corporatetitleto,feat_eventto,feat_fullpathto,feat_deptto,feat_topdeptto,feat_regionto,]

# %%
x_data = data.drop('fired',axis=1)
labels = data['fired']

x_data.head()
# Out:
#    userid  gradeto       subfamilynameto           corporatetitleto  \
# 0    1000       15     Product Marketing       VP Product Marketing
# 1   10000       10  Software Engineering           Senior Developer
# 2   10001       10  Software Engineering  Senior Research Developer
# 3   10002        7  Test Engineering R&D           Testing Engineer
# 4   10003        9  Software Engineering                  Developer
#
#        eventto                 fullpathto                            deptto  \
# 0  Data Change                    ProdMkt                 Product Marketing
# 1  Data Change          FutureTechSecPlat       Secure Platform Development
# 2     Transfer  R&DPDOLinuxKICSNetwIndPDK  KICS for Networks Industrial PDK
# 3  Data Change       R&DIDOIntDevPlatform              Platform Development
# 4  Data Change                      InIPA                     Privacy Audit
#
#     topdeptto regionto  agefake  classfake groupfake
# 0     ProdMkt   Russia       77          1         A
# 1  FutureTech   Russia       77          1         A
# 2         PDO   Russia       77          1         A
# 3         IDO   Russia       77          1         A
# 4         InI   Russia       77          1         A

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data,labels, test_size=0.33, random_state=101)

input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=100,num_epochs=1000,shuffle=True)
eval_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test,y=y_test,batch_size=10,num_epochs=1,shuffle=False)

model = tf.estimator.LinearRegressor(feature_columns=feat_cols)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Alex\AppData\Local\Temp\tmpsm3glg6s
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\Alex\\AppData\\Local\\Temp\\tmpsm3glg6s', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000002A539127128>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
model.train(input_fn=input_func,steps=1000)
# Out:
# WARNING:tensorflow:From c:\users\alex\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\estimator\inputs\queues\feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From c:\users\alex\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\estimator\inputs\queues\feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From c:\users\alex\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\training\monitored_session.py:804: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\Alex\AppData\Local\Temp\tmpsm3glg6s\model.ckpt.
# INFO:tensorflow:loss = 64.0, step = 1
# INFO:tensorflow:global_step/sec: 267.37
# INFO:tensorflow:loss = 15.29003, step = 101 (0.374 sec)
# INFO:tensorflow:global_step/sec: 549.389
# INFO:tensorflow:loss = 20.555885, step = 201 (0.181 sec)
# INFO:tensorflow:global_step/sec: 496.374
# INFO:tensorflow:loss = 17.38963, step = 301 (0.203 sec)
# INFO:tensorflow:global_step/sec: 506.401
# INFO:tensorflow:loss = 15.22749, step = 401 (0.197 sec)
# INFO:tensorflow:global_step/sec: 547.909
# INFO:tensorflow:loss = 12.511772, step = 501 (0.183 sec)
# INFO:tensorflow:global_step/sec: 539.072
# INFO:tensorflow:loss = 9.603795, step = 601 (0.186 sec)
# INFO:tensorflow:global_step/sec: 508.906
# INFO:tensorflow:loss = 18.839825, step = 701 (0.197 sec)
# INFO:tensorflow:global_step/sec: 527.721
# INFO:tensorflow:loss = 11.059951, step = 801 (0.190 sec)
# INFO:tensorflow:global_step/sec: 537.604
# INFO:tensorflow:loss = 7.034101, step = 901 (0.184 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\Alex\AppData\Local\Temp\tmpsm3glg6s\model.ckpt.
# INFO:tensorflow:Loss for final step: 8.59626.

# %%
results = model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-04-20:05:22
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Alex\AppData\Local\Temp\tmpsm3glg6s\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-04-20:05:23
# INFO:tensorflow:Saving dict for global step 1000: average_loss = 0.18438368, global_step = 1000, label/mean = 0.5488867, loss = 1.843242, prediction/mean = 0.4392789
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: C:\Users\Alex\AppData\Local\Temp\tmpsm3glg6s\model.ckpt-1000

# %%
results
# Out:
# {'average_loss': 0.18438368,
#  'label/mean': 0.5488867,
#  'loss': 1.843242,
#  'prediction/mean': 0.4392789,
#  'global_step': 1000}

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test,batch_size=10,num_epochs=1,shuffle=False)

# %%
predictions = model.predict(pred_input_func)

# %%
my_pred = list(predictions)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Alex\AppData\Local\Temp\tmpsm3glg6s\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
for _ in my_pred:
    print(_)
    
dfpred = pd.DataFrame(my_pred)
dfpred.to_csv("pred.csv")
# Out:
# {'predictions': array([0.52932286], dtype=float32)}
# {'predictions': array([-0.37016797], dtype=float32)}
# {'predictions': array([0.28213644], dtype=float32)}
# {'predictions': array([0.12303333], dtype=float32)}
# {'predictions': array([0.95258427], dtype=float32)}
# {'predictions': array([0.71645665], dtype=float32)}
# {'predictions': array([-0.4310353], dtype=float32)}
# {'predictions': array([0.9480215], dtype=float32)}
# {'predictions': array([0.33787164], dtype=float32)}
# {'predictions': array([0.82997143], dtype=float32)}
# {'predictions': array([0.43576843], dtype=float32)}
# {'predictions': array([1.0371921], dtype=float32)}
# {'predictions': array([0.4401148], dtype=float32)}
# {'predictions': array([0.43747458], dtype=float32)}
# {'predictions': array([-0.05822266], dtype=float32)}
# {'predictions': array([0.18329701], dtype=float32)}
# {'predictions': array([-0.08753482], dtype=float32)}
# {'predictions': array([1.0798182], dtype=float32)}
# {'predictions': array([0.5056229], dtype=float32)}
# {'predictions': array([-0.58287114], dtype=float32)}
# {'predictions': array([-0.01205472], dtype=float32)}
# {'predictions': array([0.06545723], dtype=float32)}
# {'predictions': array([-0.06065361], dtype=float32)}
# {'predictions': array([0.3329944], dtype=float32)}
# {'predictions': array([0.81217265], dtype=float32)}
# {'predictions': array([0.7237309], dtype=float32)}
# {'predictions': array([0.3731606], dtype=float32)}
# {'predictions': array([0.917736], dtype=float32)}
# {'predictions': array([0.2569634], dtype=float32)}
# {'predictions': array([0.94965994], dtype=float32)}
# {'predictions': array([0.85624105], dtype=float32)}
# {'predictions': array([0.6588234], dtype=float32)}
# {'predictions': array([-0.9636585], dtype=float32)}
# {'predictions': array([-0.09876955], dtype=float32)}
# {'predictions': array([0.24293873], dtype=float32)}
# {'predictions': array([-0.2536122], dtype=float32)}
# {'predictions': array([0.891943], dtype=float32)}
# {'predictions': array([0.41902143], dtype=float32)}
# {'predictions': array([-0.20437795], dtype=float32)}
# {'predictions': array([0.07542156], dtype=float32)}
# {'predictions': array([0.05707239], dtype=float32)}
# {'predictions': array([-0.06862194], dtype=float32)}
# {'predictions': array([1.289568], dtype=float32)}
# {'predictions': array([0.8183332], dtype=float32)}
# {'predictions': array([1.0134565], dtype=float32)}
# {'predictions': array([1.0419785], dtype=float32)}
# {'predictions': array([0.04416993], dtype=float32)}
# {'predictions': array([0.26051697], dtype=float32)}
# {'predictions': array([0.13432845], dtype=float32)}
# {'predictions': array([0.83015144], dtype=float32)}
# {'predictions': array([-0.03270227], dtype=float32)}
# {'predictions': array([0.8252118], dtype=float32)}
# {'predictions': array([-0.04893178], dtype=float32)}
# {'predictions': array([0.6804043], dtype=float32)}
# {'predictions': array([0.57615715], dtype=float32)}
# {'predictions': array([0.39629835], dtype=float32)}
# {'predictions': array([0.4965707], dtype=float32)}
# {'predictions': array([0.52293795], dtype=float32)}
# {'predictions': array([0.61909854], dtype=float32)}
# {'predictions': array([1.1418498], dtype=float32)}
# {'predictions': array([0.04941174], dtype=float32)}
# {'predictions': array([-0.6711073], dtype=float32)}
# {'predictions': array([-0.02882756], dtype=float32)}
# {'predictions': array([0.99422985], dtype=float32)}
# {'predictions': array([0.9670601], dtype=float32)}
# {'predictions': array([0.7000848], dtype=float32)}
# {'predictions': array([0.73966455], dtype=float32)}
# {'predictions': array([0.7284846], dtype=float32)}
# {'predictions': array([0.9962828], dtype=float32)}
# {'predictions': array([0.78035474], dtype=float32)}
# {'predictions': array([0.66459453], dtype=float32)}
# {'predictions': array([0.95441896], dtype=float32)}
# {'predictions': array([0.6385102], dtype=float32)}
# {'predictions': array([0.13338473], dtype=float32)}
# {'predictions': array([1.0213996], dtype=float32)}
# {'predictions': array([0.54168725], dtype=float32)}
# {'predictions': array([-0.07787227], dtype=float32)}
# {'predictions': array([0.28457364], dtype=float32)}
# {'predictions': array([-0.08812357], dtype=float32)}
# {'predictions': array([0.5643338], dtype=float32)}
# {'predictions': array([1.0970572], dtype=float32)}
# {'predictions': array([1.4865127], dtype=float32)}
# {'predictions': array([0.43176928], dtype=float32)}
# {'predictions': array([0.32417575], dtype=float32)}
# {'predictions': array([0.906169], dtype=float32)}
# {'predictions': array([0.3733932], dtype=float32)}
# {'predictions': array([-0.12968174], dtype=float32)}
# {'predictions': array([0.74877745], dtype=float32)}
# {'predictions': array([-0.44188088], dtype=float32)}
# {'predictions': array([0.4556123], dtype=float32)}
# {'predictions': array([0.9805447], dtype=float32)}
# {'predictions': array([0.95428175], dtype=float32)}
# {'predictions': array([0.24614519], dtype=float32)}
# {'predictions': array([-0.39923453], dtype=float32)}
# {'predictions': array([1.3105032], dtype=float32)}
# {'predictions': array([0.42522964], dtype=float32)}
# {'predictions': array([0.6340035], dtype=float32)}
# {'predictions': array([0.93609744], dtype=float32)}
# {'predictions': array([0.16888258], dtype=float32)}
# {'predictions': array([0.28674498], dtype=float32)}
# {'predictions': array([0.4464943], dtype=float32)}
# {'predictions': array([1.019825], dtype=float32)}
# {'predictions': array([0.8558805], dtype=float32)}
# {'predictions': array([0.17681697], dtype=float32)}
# {'predictions': array([-0.56233585], dtype=float32)}
# {'predictions': array([0.05985653], dtype=float32)}
# {'predictions': array([0.461289], dtype=float32)}
# {'predictions': array([0.7466923], dtype=float32)}
# {'predictions': array([-0.65655494], dtype=float32)}
# {'predictions': array([1.049884], dtype=float32)}
# {'predictions': array([0.38692936], dtype=float32)}
# {'predictions': array([0.8130151], dtype=float32)}
# {'predictions': array([1.2935176], dtype=float32)}
# {'predictions': array([-0.2444005], dtype=float32)}
# {'predictions': array([-0.30924252], dtype=float32)}
# {'predictions': array([1.1474844], dtype=float32)}
# {'predictions': array([-0.06714336], dtype=float32)}
# {'predictions': array([0.78982264], dtype=float32)}
# {'predictions': array([1.0776519], dtype=float32)}
# {'predictions': array([0.25164172], dtype=float32)}
# {'predictions': array([1.0046428], dtype=float32)}
# {'predictions': array([0.936021], dtype=float32)}
# {'predictions': array([-0.16154727], dtype=float32)}
# {'predictions': array([-0.26970795], dtype=float32)}
# {'predictions': array([0.28355405], dtype=float32)}
# {'predictions': array([1.1015295], dtype=float32)}
# {'predictions': array([-0.13217995], dtype=float32)}
# {'predictions': array([0.49370316], dtype=float32)}
# {'predictions': array([0.0315068], dtype=float32)}
# {'predictions': array([0.88321453], dtype=float32)}
# {'predictions': array([1.1714935], dtype=float32)}
# {'predictions': array([1.2108272], dtype=float32)}
# {'predictions': array([-0.33314833], dtype=float32)}
# {'predictions': array([0.37476057], dtype=float32)}
# {'predictions': array([0.24228147], dtype=float32)}
# {'predictions': array([-0.19463596], dtype=float32)}
# {'predictions': array([-0.4115769], dtype=float32)}
# {'predictions': array([0.68836987], dtype=float32)}
# {'predictions': array([0.79035974], dtype=float32)}
# {'predictions': array([0.805174], dtype=float32)}
# {'predictions': array([0.3613771], dtype=float32)}
# {'predictions': array([0.8939714], dtype=float32)}
# {'predictions': array([0.753337], dtype=float32)}
# {'predictions': array([0.47289932], dtype=float32)}
# {'predictions': array([0.4361521], dtype=float32)}
# {'predictions': array([0.27039984], dtype=float32)}
# {'predictions': array([0.19138542], dtype=float32)}
# {'predictions': array([0.5865756], dtype=float32)}
# {'predictions': array([0.53092], dtype=float32)}
# {'predictions': array([0.7564856], dtype=float32)}
# {'predictions': array([-1.0826341], dtype=float32)}
# {'predictions': array([0.15285346], dtype=float32)}
# {'predictions': array([0.8274905], dtype=float32)}
# {'predictions': array([0.01899942], dtype=float32)}
# {'predictions': array([-0.06591668], dtype=float32)}
# {'predictions': array([0.00542661], dtype=float32)}
# {'predictions': array([0.2729232], dtype=float32)}
# {'predictions': array([0.0200506], dtype=float32)}
# {'predictions': array([0.7091169], dtype=float32)}
# {'predictions': array([0.9340532], dtype=float32)}
# {'predictions': array([1.0110701], dtype=float32)}
# {'predictions': array([0.9092915], dtype=float32)}
# {'predictions': array([1.01154], dtype=float32)}
# {'predictions': array([0.0023856], dtype=float32)}
# {'predictions': array([0.26607332], dtype=float32)}
# {'predictions': array([1.1909894], dtype=float32)}
# {'predictions': array([0.7386322], dtype=float32)}
# {'predictions': array([0.8528514], dtype=float32)}
# {'predictions': array([0.8544637], dtype=float32)}
# {'predictions': array([0.7260714], dtype=float32)}
# {'predictions': array([0.94625], dtype=float32)}
# {'predictions': array([-0.05404698], dtype=float32)}
# {'predictions': array([0.2906526], dtype=float32)}
# {'predictions': array([-0.29448336], dtype=float32)}
# {'predictions': array([1.0245422], dtype=float32)}
# {'predictions': array([0.3856922], dtype=float32)}
# {'predictions': array([1.2534086], dtype=float32)}
# {'predictions': array([-0.46443963], dtype=float32)}
# {'predictions': array([1.0015764], dtype=float32)}
# {'predictions': array([0.6047652], dtype=float32)}
# {'predictions': array([0.61235064], dtype=float32)}
# {'predictions': array([-0.01220823], dtype=float32)}
# {'predictions': array([0.6172216], dtype=float32)}
# {'predictions': array([-0.00048772], dtype=float32)}
# {'predictions': array([-0.4792237], dtype=float32)}
# {'predictions': array([1.1884168], dtype=float32)}
# {'predictions': array([-0.0708837], dtype=float32)}
# {'predictions': array([0.45953068], dtype=float32)}
# {'predictions': array([0.85437006], dtype=float32)}
# {'predictions': array([0.30255646], dtype=float32)}
# {'predictions': array([-0.09989885], dtype=float32)}
# {'predictions': array([0.10988437], dtype=float32)}
# {'predictions': array([0.58145976], dtype=float32)}
# {'predictions': array([-0.24304584], dtype=float32)}
# {'predictions': array([0.7355214], dtype=float32)}
# {'predictions': array([0.22904801], dtype=float32)}
# {'predictions': array([-0.13160819], dtype=float32)}
# {'predictions': array([0.14798662], dtype=float32)}
# {'predictions': array([-0.34535015], dtype=float32)}
# {'predictions': array([0.40217093], dtype=float32)}
# {'predictions': array([1.0344604], dtype=float32)}
# {'predictions': array([0.85990095], dtype=float32)}
# {'predictions': array([0.5543024], dtype=float32)}
# {'predictions': array([0.67629844], dtype=float32)}
# {'predictions': array([0.38443932], dtype=float32)}
# {'predictions': array([0.3365291], dtype=float32)}
# {'predictions': array([1.0051732], dtype=float32)}
# {'predictions': array([-0.13304445], dtype=float32)}
# {'predictions': array([0.1405502], dtype=float32)}
# {'predictions': array([0.39751562], dtype=float32)}
# {'predictions': array([0.12814462], dtype=float32)}
# {'predictions': array([0.64724493], dtype=float32)}
# {'predictions': array([0.08548483], dtype=float32)}
# {'predictions': array([0.9241818], dtype=float32)}
# {'predictions': array([0.65047693], dtype=float32)}
# {'predictions': array([-0.10444687], dtype=float32)}
# {'predictions': array([-0.00237528], dtype=float32)}
# {'predictions': array([1.0500269], dtype=float32)}
# {'predictions': array([0.85470974], dtype=float32)}
# {'predictions': array([-0.5145806], dtype=float32)}
# {'predictions': array([0.04127755], dtype=float32)}
# {'predictions': array([0.9621834], dtype=float32)}
# {'predictions': array([-0.4156745], dtype=float32)}
# {'predictions': array([-0.49544564], dtype=float32)}
# {'predictions': array([0.4351459], dtype=float32)}
# {'predictions': array([0.372755], dtype=float32)}
# {'predictions': array([0.20285863], dtype=float32)}
# {'predictions': array([1.1430926], dtype=float32)}
# {'predictions': array([1.1275139], dtype=float32)}
# {'predictions': array([1.0039775], dtype=float32)}
# {'predictions': array([-0.01341385], dtype=float32)}
# {'predictions': array([0.24074179], dtype=float32)}
# {'predictions': array([-0.3416203], dtype=float32)}
# {'predictions': array([0.5135642], dtype=float32)}
# {'predictions': array([1.3487315], dtype=float32)}
# {'predictions': array([0.6591233], dtype=float32)}
# {'predictions': array([-0.12783459], dtype=float32)}
# {'predictions': array([-0.01794551], dtype=float32)}
# {'predictions': array([0.57573897], dtype=float32)}
# {'predictions': array([-0.03937153], dtype=float32)}
# {'predictions': array([0.84481853], dtype=float32)}
# {'predictions': array([0.02169245], dtype=float32)}
# {'predictions': array([-0.28098473], dtype=float32)}
# {'predictions': array([0.98922825], dtype=float32)}
# {'predictions': array([0.94019973], dtype=float32)}
# {'predictions': array([-0.19377565], dtype=float32)}
# {'predictions': array([1.0449454], dtype=float32)}
# {'predictions': array([0.03245855], dtype=float32)}
# {'predictions': array([0.40454456], dtype=float32)}
# {'predictions': array([0.22642836], dtype=float32)}
# {'predictions': array([0.26958925], dtype=float32)}
# {'predictions': array([0.9696733], dtype=float32)}
# {'predictions': array([0.30649933], dtype=float32)}
# {'predictions': array([0.45252374], dtype=float32)}
# {'predictions': array([-0.10122261], dtype=float32)}
# {'predictions': array([0.6069742], dtype=float32)}
# {'predictions': array([0.03538168], dtype=float32)}
# {'predictions': array([0.93080235], dtype=float32)}
# {'predictions': array([0.49371353], dtype=float32)}
# {'predictions': array([-0.06916413], dtype=float32)}
# {'predictions': array([0.0905173], dtype=float32)}
# {'predictions': array([-0.36819708], dtype=float32)}
# {'predictions': array([0.6813102], dtype=float32)}
# {'predictions': array([-0.5024257], dtype=float32)}
# {'predictions': array([0.38740903], dtype=float32)}
# {'predictions': array([0.98208], dtype=float32)}
# {'predictions': array([0.9057966], dtype=float32)}
# {'predictions': array([-0.15993956], dtype=float32)}
# {'predictions': array([0.6465436], dtype=float32)}
# {'predictions': array([1.2358099], dtype=float32)}
# {'predictions': array([0.97463924], dtype=float32)}
# {'predictions': array([0.92917705], dtype=float32)}
# {'predictions': array([1.2849251], dtype=float32)}
# {'predictions': array([0.8833189], dtype=float32)}
# {'predictions': array([0.6642535], dtype=float32)}
# {'predictions': array([0.48299992], dtype=float32)}
# {'predictions': array([1.4318297], dtype=float32)}
# {'predictions': array([-0.56033516], dtype=float32)}
# {'predictions': array([0.21687871], dtype=float32)}
# {'predictions': array([1.0355474], dtype=float32)}
# {'predictions': array([-0.20408544], dtype=float32)}
# {'predictions': array([0.60929585], dtype=float32)}
# {'predictions': array([0.6625134], dtype=float32)}
# {'predictions': array([0.44665852], dtype=float32)}
# {'predictions': array([0.8845638], dtype=float32)}
# {'predictions': array([1.0413848], dtype=float32)}
# {'predictions': array([0.89271903], dtype=float32)}
# {'predictions': array([0.32213506], dtype=float32)}
# {'predictions': array([0.12299659], dtype=float32)}
# {'predictions': array([0.02812573], dtype=float32)}
# {'predictions': array([-0.18109259], dtype=float32)}
# {'predictions': array([0.7695832], dtype=float32)}
# {'predictions': array([0.9617933], dtype=float32)}
# {'predictions': array([0.8854097], dtype=float32)}
# {'predictions': array([-0.04640967], dtype=float32)}
# {'predictions': array([0.3142568], dtype=float32)}
# {'predictions': array([1.0445223], dtype=float32)}
# {'predictions': array([1.1814215], dtype=float32)}
# {'predictions': array([0.6684793], dtype=float32)}
# {'predictions': array([0.58371115], dtype=float32)}
# {'predictions': array([-0.2135962], dtype=float32)}
# {'predictions': array([0.02813771], dtype=float32)}
# {'predictions': array([0.87714404], dtype=float32)}
# {'predictions': array([0.05380031], dtype=float32)}
# {'predictions': array([-0.42701265], dtype=float32)}
# {'predictions': array([1.0190288], dtype=float32)}
# {'predictions': array([0.0074529], dtype=float32)}
# {'predictions': array([0.8065552], dtype=float32)}
# {'predictions': array([1.5038958], dtype=float32)}
# {'predictions': array([0.99265677], dtype=float32)}
# {'predictions': array([0.8031814], dtype=float32)}
# {'predictions': array([-0.02130521], dtype=float32)}
# {'predictions': array([-0.0347302], dtype=float32)}
# {'predictions': array([1.0162675], dtype=float32)}
# {'predictions': array([0.11467337], dtype=float32)}
# {'predictions': array([1.0915241], dtype=float32)}
# {'predictions': array([1.2533628], dtype=float32)}
# {'predictions': array([0.81335765], dtype=float32)}
# {'predictions': array([1.0304668], dtype=float32)}
# {'predictions': array([0.7526416], dtype=float32)}
# {'predictions': array([0.5810679], dtype=float32)}
# {'predictions': array([0.8915219], dtype=float32)}
# {'predictions': array([0.21700695], dtype=float32)}
# {'predictions': array([0.9357538], dtype=float32)}
# {'predictions': array([-0.15325725], dtype=float32)}
# {'predictions': array([-0.02062932], dtype=float32)}
# {'predictions': array([0.7973154], dtype=float32)}
# {'predictions': array([-0.19859478], dtype=float32)}
# {'predictions': array([0.8280746], dtype=float32)}
# {'predictions': array([0.4363757], dtype=float32)}
# {'predictions': array([-0.58787817], dtype=float32)}
# {'predictions': array([1.3058038], dtype=float32)}
# {'predictions': array([0.6169863], dtype=float32)}
# {'predictions': array([0.24530181], dtype=float32)}
# {'predictions': array([-0.01324291], dtype=float32)}
# {'predictions': array([-0.06103519], dtype=float32)}
# {'predictions': array([0.17181757], dtype=float32)}
# {'predictions': array([0.73710734], dtype=float32)}
# {'predictions': array([0.2026419], dtype=float32)}
# {'predictions': array([0.7521793], dtype=float32)}
# {'predictions': array([1.0632577], dtype=float32)}
# {'predictions': array([-0.2071664], dtype=float32)}
# {'predictions': array([0.56033075], dtype=float32)}
# {'predictions': array([0.48478436], dtype=float32)}
# {'predictions': array([0.7879085], dtype=float32)}
# {'predictions': array([-0.09261987], dtype=float32)}
# {'predictions': array([0.82528377], dtype=float32)}
# {'predictions': array([-0.26259932], dtype=float32)}
# {'predictions': array([0.6125386], dtype=float32)}
# {'predictions': array([0.06915045], dtype=float32)}
# {'predictions': array([-0.15102714], dtype=float32)}
# {'predictions': array([0.62205225], dtype=float32)}
# {'predictions': array([-0.10714782], dtype=float32)}
# {'predictions': array([-0.07281826], dtype=float32)}
# {'predictions': array([0.14012259], dtype=float32)}
# {'predictions': array([0.38606617], dtype=float32)}
# {'predictions': array([1.0422281], dtype=float32)}
# {'predictions': array([-0.3454836], dtype=float32)}
# {'predictions': array([1.000715], dtype=float32)}
# {'predictions': array([0.24551147], dtype=float32)}
# {'predictions': array([1.0992554], dtype=float32)}
# {'predictions': array([0.4240092], dtype=float32)}
# {'predictions': array([0.9509928], dtype=float32)}
# {'predictions': array([0.8186213], dtype=float32)}
# {'predictions': array([0.7260982], dtype=float32)}
# {'predictions': array([1.0762872], dtype=float32)}
# {'predictions': array([0.40745294], dtype=float32)}
# {'predictions': array([1.0244355], dtype=float32)}
# {'predictions': array([0.8558762], dtype=float32)}
# {'predictions': array([-0.19270733], dtype=float32)}
# {'predictions': array([0.07727429], dtype=float32)}
# {'predictions': array([0.0148118], dtype=float32)}
# {'predictions': array([0.5220307], dtype=float32)}
# {'predictions': array([1.0925459], dtype=float32)}
# {'predictions': array([0.31611064], dtype=float32)}
# {'predictions': array([-0.10776211], dtype=float32)}
# {'predictions': array([-0.31962883], dtype=float32)}
# {'predictions': array([1.0745513], dtype=float32)}
# {'predictions': array([1.0838265], dtype=float32)}
# {'predictions': array([0.11528676], dtype=float32)}
# {'predictions': array([0.0401315], dtype=float32)}
# {'predictions': array([0.43925872], dtype=float32)}
# {'predictions': array([-0.05814222], dtype=float32)}
# {'predictions': array([0.45262274], dtype=float32)}
# {'predictions': array([0.6434671], dtype=float32)}
# {'predictions': array([1.0062463], dtype=float32)}
# {'predictions': array([0.3053303], dtype=float32)}
# {'predictions': array([1.0544853], dtype=float32)}
# {'predictions': array([-0.25655416], dtype=float32)}
# {'predictions': array([-0.07201143], dtype=float32)}
# {'predictions': array([0.17385098], dtype=float32)}
# {'predictions': array([0.4298056], dtype=float32)}
# {'predictions': array([1.1934304], dtype=float32)}
# {'predictions': array([0.17728856], dtype=float32)}
# {'predictions': array([-0.15060702], dtype=float32)}
# {'predictions': array([0.70853275], dtype=float32)}
# {'predictions': array([0.21287811], dtype=float32)}
# {'predictions': array([-0.32674178], dtype=float32)}
# {'predictions': array([0.26613042], dtype=float32)}
# {'predictions': array([0.28304258], dtype=float32)}
# {'predictions': array([0.3745962], dtype=float32)}
# {'predictions': array([0.40490028], dtype=float32)}
# {'predictions': array([0.7972017], dtype=float32)}
# {'predictions': array([0.50992185], dtype=float32)}
# {'predictions': array([-0.19194445], dtype=float32)}
# {'predictions': array([0.84908485], dtype=float32)}
# {'predictions': array([1.1147264], dtype=float32)}
# {'predictions': array([0.73180467], dtype=float32)}
# {'predictions': array([1.02705], dtype=float32)}
# {'predictions': array([0.53314066], dtype=float32)}
# {'predictions': array([-0.02876095], dtype=float32)}
# {'predictions': array([0.2594454], dtype=float32)}
# {'predictions': array([-0.6399306], dtype=float32)}
# {'predictions': array([0.23837265], dtype=float32)}
# {'predictions': array([0.23974085], dtype=float32)}
# {'predictions': array([0.51797116], dtype=float32)}
# {'predictions': array([-0.08926725], dtype=float32)}
# {'predictions': array([-0.00851838], dtype=float32)}
# {'predictions': array([-0.03993926], dtype=float32)}
# {'predictions': array([0.9573874], dtype=float32)}
# {'predictions': array([1.0194021], dtype=float32)}
# {'predictions': array([-0.03536812], dtype=float32)}
# {'predictions': array([0.38185534], dtype=float32)}
# {'predictions': array([0.23133776], dtype=float32)}
# {'predictions': array([0.3996383], dtype=float32)}
# {'predictions': array([0.18863371], dtype=float32)}
# {'predictions': array([0.24237904], dtype=float32)}
# {'predictions': array([0.91748106], dtype=float32)}
# {'predictions': array([0.2599077], dtype=float32)}
# {'predictions': array([1.1922926], dtype=float32)}
# {'predictions': array([0.21814758], dtype=float32)}
# {'predictions': array([0.97379875], dtype=float32)}
# {'predictions': array([-0.55734956], dtype=float32)}
# {'predictions': array([1.005733], dtype=float32)}
# {'predictions': array([1.1295189], dtype=float32)}
# {'predictions': array([-0.04056884], dtype=float32)}
# {'predictions': array([0.24540937], dtype=float32)}
# {'predictions': array([0.7183887], dtype=float32)}
# {'predictions': array([0.6232101], dtype=float32)}
# {'predictions': array([-0.3038924], dtype=float32)}
# {'predictions': array([1.0903083], dtype=float32)}
# {'predictions': array([0.31132722], dtype=float32)}
# {'predictions': array([0.07757702], dtype=float32)}
# {'predictions': array([-0.02523804], dtype=float32)}
# {'predictions': array([0.3638679], dtype=float32)}
# {'predictions': array([-0.27808264], dtype=float32)}
# {'predictions': array([0.6792821], dtype=float32)}
# {'predictions': array([-0.5950468], dtype=float32)}
# {'predictions': array([1.0572525], dtype=float32)}
# {'predictions': array([0.03981083], dtype=float32)}
# {'predictions': array([-0.042388], dtype=float32)}
# {'predictions': array([0.27921066], dtype=float32)}
# {'predictions': array([0.39150482], dtype=float32)}
# {'predictions': array([1.0756143], dtype=float32)}
# {'predictions': array([1.0302982], dtype=float32)}
# {'predictions': array([1.0318431], dtype=float32)}
# {'predictions': array([0.10741051], dtype=float32)}
# {'predictions': array([0.97456926], dtype=float32)}
# {'predictions': array([0.4045982], dtype=float32)}
# {'predictions': array([0.2258276], dtype=float32)}
# {'predictions': array([0.92432845], dtype=float32)}
# {'predictions': array([1.2898384], dtype=float32)}
# {'predictions': array([0.6798468], dtype=float32)}
# {'predictions': array([1.0051596], dtype=float32)}
# {'predictions': array([1.0525373], dtype=float32)}
# {'predictions': array([0.07429648], dtype=float32)}
# {'predictions': array([-0.49016723], dtype=float32)}
# {'predictions': array([-0.14892846], dtype=float32)}
# {'predictions': array([-0.07441378], dtype=float32)}
# {'predictions': array([0.09300288], dtype=float32)}
# {'predictions': array([0.11444472], dtype=float32)}
# {'predictions': array([0.71913767], dtype=float32)}
# {'predictions': array([0.79698294], dtype=float32)}
# {'predictions': array([0.28854662], dtype=float32)}
# {'predictions': array([-0.1025121], dtype=float32)}
# {'predictions': array([0.1444062], dtype=float32)}
# {'predictions': array([1.0272468], dtype=float32)}
# {'predictions': array([-0.11388444], dtype=float32)}
# {'predictions': array([0.17570621], dtype=float32)}
# {'predictions': array([0.8991219], dtype=float32)}
# {'predictions': array([-0.10600249], dtype=float32)}
# {'predictions': array([0.81931615], dtype=float32)}
# {'predictions': array([0.38577464], dtype=float32)}
# {'predictions': array([0.09594729], dtype=float32)}
# {'predictions': array([0.17258072], dtype=float32)}
# {'predictions': array([0.27117795], dtype=float32)}
# {'predictions': array([0.22516143], dtype=float32)}
# {'predictions': array([0.2519], dtype=float32)}
# {'predictions': array([-0.31630048], dtype=float32)}
# {'predictions': array([0.43621096], dtype=float32)}
# {'predictions': array([0.55654633], dtype=float32)}
# {'predictions': array([0.10729523], dtype=float32)}
# {'predictions': array([-0.0464097], dtype=float32)}
# {'predictions': array([0.0304084], dtype=float32)}
# {'predictions': array([0.05645907], dtype=float32)}
# {'predictions': array([0.35214373], dtype=float32)}
# {'predictions': array([1.2275256], dtype=float32)}
# {'predictions': array([0.64860034], dtype=float32)}
# {'predictions': array([0.48158094], dtype=float32)}
# {'predictions': array([0.94463867], dtype=float32)}
# {'predictions': array([0.3591918], dtype=float32)}
# {'predictions': array([1.0114096], dtype=float32)}
# {'predictions': array([0.59635997], dtype=float32)}
# {'predictions': array([0.54951835], dtype=float32)}
# {'predictions': array([-0.02166883], dtype=float32)}
# {'predictions': array([0.63369143], dtype=float32)}
# {'predictions': array([0.47918734], dtype=float32)}
# {'predictions': array([0.06796982], dtype=float32)}
# {'predictions': array([-0.0159739], dtype=float32)}
# {'predictions': array([1.0012255], dtype=float32)}
# {'predictions': array([0.51352835], dtype=float32)}
# {'predictions': array([-0.09111104], dtype=float32)}
# {'predictions': array([-0.0029541], dtype=float32)}
# {'predictions': array([-0.21574396], dtype=float32)}
# {'predictions': array([1.0981542], dtype=float32)}
# {'predictions': array([1.0832869], dtype=float32)}
# {'predictions': array([1.1835827], dtype=float32)}
# {'predictions': array([1.0670295], dtype=float32)}
# {'predictions': array([0.20698565], dtype=float32)}
# {'predictions': array([-0.56399554], dtype=float32)}
# {'predictions': array([0.10375866], dtype=float32)}
# {'predictions': array([0.8585082], dtype=float32)}
# {'predictions': array([0.03896397], dtype=float32)}
# {'predictions': array([0.82942295], dtype=float32)}
# {'predictions': array([1.1755943], dtype=float32)}
# {'predictions': array([-0.79580456], dtype=float32)}
# {'predictions': array([0.34310395], dtype=float32)}
# {'predictions': array([0.2706087], dtype=float32)}
# {'predictions': array([0.15640926], dtype=float32)}
# {'predictions': array([-0.19299254], dtype=float32)}
# {'predictions': array([0.1479652], dtype=float32)}
# {'predictions': array([0.2555406], dtype=float32)}
# {'predictions': array([-0.00989532], dtype=float32)}
# {'predictions': array([-0.08861498], dtype=float32)}
# {'predictions': array([0.93965477], dtype=float32)}
# {'predictions': array([0.17173663], dtype=float32)}
# {'predictions': array([0.5944114], dtype=float32)}
# {'predictions': array([0.78069496], dtype=float32)}
# {'predictions': array([-0.3825158], dtype=float32)}
# {'predictions': array([-0.35904112], dtype=float32)}
# {'predictions': array([0.26878545], dtype=float32)}
# {'predictions': array([0.49172994], dtype=float32)}
# {'predictions': array([-0.12577352], dtype=float32)}
# {'predictions': array([-0.30681702], dtype=float32)}
# {'predictions': array([0.3552204], dtype=float32)}
# {'predictions': array([0.24093938], dtype=float32)}
# {'predictions': array([0.60092604], dtype=float32)}
# {'predictions': array([0.9068724], dtype=float32)}
# {'predictions': array([0.5824574], dtype=float32)}
# {'predictions': array([-0.5489069], dtype=float32)}
# {'predictions': array([0.99777335], dtype=float32)}
# {'predictions': array([0.04582223], dtype=float32)}
# {'predictions': array([0.0331369], dtype=float32)}
# {'predictions': array([0.8260343], dtype=float32)}
# {'predictions': array([0.5171097], dtype=float32)}
# {'predictions': array([-0.14217356], dtype=float32)}
# {'predictions': array([0.14579266], dtype=float32)}
# {'predictions': array([0.1652526], dtype=float32)}
# {'predictions': array([1.0607407], dtype=float32)}
# {'predictions': array([0.62264276], dtype=float32)}
# {'predictions': array([1.0796484], dtype=float32)}
# {'predictions': array([0.7737261], dtype=float32)}
# {'predictions': array([0.89706445], dtype=float32)}
# {'predictions': array([0.7882975], dtype=float32)}
# {'predictions': array([0.94614935], dtype=float32)}
# {'predictions': array([-0.14217865], dtype=float32)}
# {'predictions': array([0.936437], dtype=float32)}
# {'predictions': array([0.12523805], dtype=float32)}
# {'predictions': array([1.5049437], dtype=float32)}
# {'predictions': array([1.0800167], dtype=float32)}
# {'predictions': array([0.70197546], dtype=float32)}
# {'predictions': array([1.1750731], dtype=float32)}
# {'predictions': array([0.13509819], dtype=float32)}
# {'predictions': array([-0.12645802], dtype=float32)}
# {'predictions': array([1.2268246], dtype=float32)}
# {'predictions': array([-0.14595714], dtype=float32)}
# {'predictions': array([-0.6938797], dtype=float32)}
# {'predictions': array([0.33135003], dtype=float32)}
# {'predictions': array([0.6143446], dtype=float32)}
# {'predictions': array([-0.39447588], dtype=float32)}
# {'predictions': array([0.22769058], dtype=float32)}
# {'predictions': array([0.28781882], dtype=float32)}
# {'predictions': array([-0.34376255], dtype=float32)}
# {'predictions': array([0.37108108], dtype=float32)}
# {'predictions': array([0.0610313], dtype=float32)}
# {'predictions': array([0.01262388], dtype=float32)}
# {'predictions': array([0.0354326], dtype=float32)}
# {'predictions': array([-0.05667821], dtype=float32)}
# {'predictions': array([1.0638081], dtype=float32)}
# {'predictions': array([0.21679339], dtype=float32)}
# {'predictions': array([0.69188404], dtype=float32)}
# {'predictions': array([0.37119398], dtype=float32)}
# {'predictions': array([0.99549395], dtype=float32)}
# {'predictions': array([0.8241446], dtype=float32)}
# {'predictions': array([0.111335], dtype=float32)}
# {'predictions': array([0.7371104], dtype=float32)}
# {'predictions': array([0.42651623], dtype=float32)}
# {'predictions': array([1.0970105], dtype=float32)}
# {'predictions': array([0.81219447], dtype=float32)}
# {'predictions': array([0.16712579], dtype=float32)}
# {'predictions': array([-0.57575065], dtype=float32)}
# {'predictions': array([0.12592822], dtype=float32)}
# {'predictions': array([0.8908886], dtype=float32)}
# {'predictions': array([0.5868894], dtype=float32)}
# {'predictions': array([0.82092726], dtype=float32)}
# {'predictions': array([0.05269542], dtype=float32)}
# {'predictions': array([0.34366724], dtype=float32)}
# {'predictions': array([1.6130201], dtype=float32)}
# {'predictions': array([0.6943301], dtype=float32)}
# {'predictions': array([1.0614151], dtype=float32)}
# {'predictions': array([0.49188396], dtype=float32)}
# {'predictions': array([-0.2918895], dtype=float32)}
# {'predictions': array([1.2218028], dtype=float32)}
# {'predictions': array([0.5755718], dtype=float32)}
# {'predictions': array([0.8834156], dtype=float32)}
# {'predictions': array([1.0377815], dtype=float32)}
# {'predictions': array([0.5699064], dtype=float32)}
# {'predictions': array([0.8632445], dtype=float32)}
# {'predictions': array([-0.14904559], dtype=float32)}
# {'predictions': array([0.45633528], dtype=float32)}
# {'predictions': array([-0.09967789], dtype=float32)}
# {'predictions': array([1.0199744], dtype=float32)}
# {'predictions': array([1.1276459], dtype=float32)}
# {'predictions': array([-0.22376192], dtype=float32)}
# {'predictions': array([0.41999665], dtype=float32)}
# {'predictions': array([0.48878166], dtype=float32)}
# {'predictions': array([-0.5154791], dtype=float32)}
# {'predictions': array([0.21571818], dtype=float32)}
# {'predictions': array([0.6780373], dtype=float32)}
# {'predictions': array([1.052012], dtype=float32)}
# {'predictions': array([0.7928313], dtype=float32)}
# {'predictions': array([0.13900396], dtype=float32)}
# {'predictions': array([0.37969306], dtype=float32)}
# {'predictions': array([1.0946617], dtype=float32)}
# {'predictions': array([0.20087919], dtype=float32)}
# {'predictions': array([0.5905963], dtype=float32)}
# {'predictions': array([0.42289534], dtype=float32)}
# {'predictions': array([1.0682278], dtype=float32)}
# {'predictions': array([0.5137155], dtype=float32)}
# {'predictions': array([0.68117976], dtype=float32)}
# {'predictions': array([0.21776554], dtype=float32)}
# {'predictions': array([0.8595964], dtype=float32)}
# {'predictions': array([-0.08143751], dtype=float32)}
# {'predictions': array([0.6704209], dtype=float32)}
# {'predictions': array([0.5196879], dtype=float32)}
# {'predictions': array([0.04549416], dtype=float32)}
# {'predictions': array([0.8378571], dtype=float32)}
# {'predictions': array([0.6926294], dtype=float32)}
# {'predictions': array([0.56655115], dtype=float32)}
# {'predictions': array([-0.04288287], dtype=float32)}
# {'predictions': array([1.0617043], dtype=float32)}
# {'predictions': array([0.05481432], dtype=float32)}
# {'predictions': array([0.5880151], dtype=float32)}
# {'predictions': array([-0.59026253], dtype=float32)}
# {'predictions': array([0.7797196], dtype=float32)}
# {'predictions': array([0.68730015], dtype=float32)}
# {'predictions': array([0.15077218], dtype=float32)}
# {'predictions': array([0.84372365], dtype=float32)}
# {'predictions': array([0.11564889], dtype=float32)}
# {'predictions': array([0.402773], dtype=float32)}
# {'predictions': array([0.6902803], dtype=float32)}
# {'predictions': array([-0.1401105], dtype=float32)}
# {'predictions': array([-0.29861063], dtype=float32)}
# {'predictions': array([0.02740263], dtype=float32)}
# {'predictions': array([0.3401069], dtype=float32)}
# {'predictions': array([0.7222542], dtype=float32)}
# {'predictions': array([-0.51902956], dtype=float32)}
# {'predictions': array([0.28740075], dtype=float32)}
# {'predictions': array([0.11463632], dtype=float32)}
# {'predictions': array([-0.02416728], dtype=float32)}
# {'predictions': array([0.6020326], dtype=float32)}
# {'predictions': array([0.1969347], dtype=float32)}
# {'predictions': array([-0.1922287], dtype=float32)}
# {'predictions': array([0.59102875], dtype=float32)}
# {'predictions': array([0.66858864], dtype=float32)}
# {'predictions': array([-0.33818918], dtype=float32)}
# {'predictions': array([0.39234364], dtype=float32)}
# {'predictions': array([-0.16076228], dtype=float32)}
# {'predictions': array([0.9231701], dtype=float32)}
# {'predictions': array([-0.03553275], dtype=float32)}
# {'predictions': array([0.7473599], dtype=float32)}
# {'predictions': array([0.71061325], dtype=float32)}
# {'predictions': array([0.36982527], dtype=float32)}
# {'predictions': array([0.91291773], dtype=float32)}
# {'predictions': array([0.9144534], dtype=float32)}
# {'predictions': array([0.16517943], dtype=float32)}
# {'predictions': array([-0.13288096], dtype=float32)}
# {'predictions': array([1.0148048], dtype=float32)}
# {'predictions': array([1.0533776], dtype=float32)}
# {'predictions': array([0.25522533], dtype=float32)}
# {'predictions': array([0.74550486], dtype=float32)}
# {'predictions': array([0.6221596], dtype=float32)}
# {'predictions': array([0.21667203], dtype=float32)}
# {'predictions': array([0.05445554], dtype=float32)}
# {'predictions': array([0.73735404], dtype=float32)}
# {'predictions': array([0.21884924], dtype=float32)}
# {'predictions': array([0.5130362], dtype=float32)}
# {'predictions': array([-0.04974078], dtype=float32)}
# {'predictions': array([0.93014467], dtype=float32)}
# {'predictions': array([0.60416883], dtype=float32)}
# {'predictions': array([1.0774161], dtype=float32)}
# {'predictions': array([0.6648916], dtype=float32)}
# {'predictions': array([0.97912693], dtype=float32)}
# {'predictions': array([0.26809433], dtype=float32)}
# {'predictions': array([0.6414576], dtype=float32)}
# {'predictions': array([0.90088665], dtype=float32)}
# {'predictions': array([0.24547437], dtype=float32)}
# {'predictions': array([0.72082466], dtype=float32)}
# {'predictions': array([0.81980985], dtype=float32)}
# {'predictions': array([0.1314151], dtype=float32)}
# {'predictions': array([-0.33124313], dtype=float32)}
# {'predictions': array([1.0208769], dtype=float32)}
# {'predictions': array([0.69409716], dtype=float32)}
# {'predictions': array([0.80323553], dtype=float32)}
# {'predictions': array([0.20186281], dtype=float32)}
# {'predictions': array([-0.45001623], dtype=float32)}
# {'predictions': array([0.6930718], dtype=float32)}
# {'predictions': array([-0.03419276], dtype=float32)}
# {'predictions': array([1.092747], dtype=float32)}
# {'predictions': array([0.9232327], dtype=float32)}
# {'predictions': array([0.77415293], dtype=float32)}
# {'predictions': array([-0.12808475], dtype=float32)}
# {'predictions': array([0.62855047], dtype=float32)}
# {'predictions': array([-0.07096554], dtype=float32)}
# {'predictions': array([0.52710223], dtype=float32)}
# {'predictions': array([0.10554647], dtype=float32)}
# {'predictions': array([0.25495157], dtype=float32)}
# {'predictions': array([0.07181226], dtype=float32)}
# {'predictions': array([1.0811048], dtype=float32)}
# {'predictions': array([0.3839673], dtype=float32)}
# {'predictions': array([-0.05261309], dtype=float32)}
# {'predictions': array([-0.28112122], dtype=float32)}
# {'predictions': array([0.97842646], dtype=float32)}
# {'predictions': array([0.6925175], dtype=float32)}
# {'predictions': array([0.9489896], dtype=float32)}
# {'predictions': array([0.1893403], dtype=float32)}
# {'predictions': array([0.69755524], dtype=float32)}
# {'predictions': array([-0.0830524], dtype=float32)}
# {'predictions': array([-0.05110986], dtype=float32)}
# {'predictions': array([1.1713278], dtype=float32)}
# {'predictions': array([0.5426911], dtype=float32)}
# {'predictions': array([1.157376], dtype=float32)}
# {'predictions': array([0.2145116], dtype=float32)}
# {'predictions': array([0.15385893], dtype=float32)}
# {'predictions': array([-0.16992909], dtype=float32)}
# {'predictions': array([0.24700528], dtype=float32)}
# {'predictions': array([-0.03854901], dtype=float32)}
# {'predictions': array([0.73390615], dtype=float32)}
# {'predictions': array([0.77219117], dtype=float32)}
# {'predictions': array([0.46038225], dtype=float32)}
# {'predictions': array([0.2521578], dtype=float32)}
# {'predictions': array([0.69402444], dtype=float32)}
# {'predictions': array([-0.26146483], dtype=float32)}
# {'predictions': array([0.17778218], dtype=float32)}
# {'predictions': array([0.19182444], dtype=float32)}
# {'predictions': array([0.21736282], dtype=float32)}
# {'predictions': array([0.83182585], dtype=float32)}
# {'predictions': array([-0.21060857], dtype=float32)}
# {'predictions': array([0.9582028], dtype=float32)}
# {'predictions': array([1.1192304], dtype=float32)}
# {'predictions': array([0.6954024], dtype=float32)}
# {'predictions': array([-0.04481772], dtype=float32)}
# {'predictions': array([1.2413299], dtype=float32)}
# {'predictions': array([0.73553276], dtype=float32)}
# {'predictions': array([-0.24877182], dtype=float32)}
# {'predictions': array([0.859038], dtype=float32)}
# {'predictions': array([-0.18904984], dtype=float32)}
# {'predictions': array([0.0541225], dtype=float32)}
# {'predictions': array([1.0757586], dtype=float32)}
# {'predictions': array([0.14073598], dtype=float32)}
# {'predictions': array([0.12113536], dtype=float32)}
# {'predictions': array([0.5765536], dtype=float32)}
# {'predictions': array([0.69748497], dtype=float32)}
# {'predictions': array([0.2618395], dtype=float32)}
# {'predictions': array([0.03215563], dtype=float32)}
# {'predictions': array([0.11108821], dtype=float32)}
# {'predictions': array([0.48040166], dtype=float32)}
# {'predictions': array([1.0457733], dtype=float32)}
# {'predictions': array([0.04251333], dtype=float32)}
# {'predictions': array([0.6015119], dtype=float32)}
# {'predictions': array([0.9312307], dtype=float32)}
# {'predictions': array([0.11657139], dtype=float32)}
# {'predictions': array([0.5641262], dtype=float32)}
# {'predictions': array([0.43271288], dtype=float32)}
# {'predictions': array([-0.27771145], dtype=float32)}
# {'predictions': array([1.2328168], dtype=float32)}
# {'predictions': array([0.5571045], dtype=float32)}
# {'predictions': array([0.99401784], dtype=float32)}
# {'predictions': array([-0.38433585], dtype=float32)}
# {'predictions': array([0.09994582], dtype=float32)}
# {'predictions': array([0.05364396], dtype=float32)}
# {'predictions': array([0.62457705], dtype=float32)}
# {'predictions': array([-0.22012097], dtype=float32)}
# {'predictions': array([-0.09053446], dtype=float32)}
# {'predictions': array([0.25267878], dtype=float32)}
# {'predictions': array([0.7112529], dtype=float32)}
# {'predictions': array([-0.01277239], dtype=float32)}
# {'predictions': array([-0.2497819], dtype=float32)}
# {'predictions': array([0.54658777], dtype=float32)}
# {'predictions': array([0.905339], dtype=float32)}
# {'predictions': array([0.3199277], dtype=float32)}
# {'predictions': array([0.896871], dtype=float32)}
# {'predictions': array([0.97617805], dtype=float32)}
# {'predictions': array([-0.21320355], dtype=float32)}
# {'predictions': array([0.9298214], dtype=float32)}
# {'predictions': array([0.8564018], dtype=float32)}
# {'predictions': array([1.1993946], dtype=float32)}
# {'predictions': array([0.9700029], dtype=float32)}
# {'predictions': array([0.9835216], dtype=float32)}
# {'predictions': array([0.02627005], dtype=float32)}
# {'predictions': array([0.36427966], dtype=float32)}
# {'predictions': array([0.12743744], dtype=float32)}
# {'predictions': array([0.9003575], dtype=float32)}
# {'predictions': array([0.5865501], dtype=float32)}
# {'predictions': array([0.8067227], dtype=float32)}
# {'predictions': array([1.3566276], dtype=float32)}
# {'predictions': array([1.014597], dtype=float32)}
# {'predictions': array([0.38608766], dtype=float32)}
# {'predictions': array([0.952531], dtype=float32)}
# {'predictions': array([0.99424255], dtype=float32)}
# {'predictions': array([0.24897218], dtype=float32)}
# {'predictions': array([0.5782943], dtype=float32)}
# {'predictions': array([0.58087224], dtype=float32)}
# {'predictions': array([0.16490585], dtype=float32)}
# {'predictions': array([1.1275171], dtype=float32)}
# {'predictions': array([-0.24918583], dtype=float32)}
# {'predictions': array([1.3563303], dtype=float32)}
# {'predictions': array([0.6471324], dtype=float32)}
# {'predictions': array([0.3878316], dtype=float32)}
# {'predictions': array([1.0497085], dtype=float32)}
# {'predictions': array([0.45369622], dtype=float32)}
# {'predictions': array([-0.07787494], dtype=float32)}
# {'predictions': array([-0.4169121], dtype=float32)}
# {'predictions': array([0.9631971], dtype=float32)}
# {'predictions': array([-0.22344247], dtype=float32)}
# {'predictions': array([0.7479764], dtype=float32)}
# {'predictions': array([1.2173942], dtype=float32)}
# {'predictions': array([0.03693169], dtype=float32)}
# {'predictions': array([0.8910661], dtype=float32)}
# {'predictions': array([0.8009063], dtype=float32)}
# {'predictions': array([0.75915146], dtype=float32)}
# {'predictions': array([0.53853256], dtype=float32)}
# {'predictions': array([0.6528077], dtype=float32)}
# {'predictions': array([-0.42669365], dtype=float32)}
# {'predictions': array([0.01461194], dtype=float32)}
# {'predictions': array([0.10838168], dtype=float32)}
# {'predictions': array([0.90838206], dtype=float32)}
# {'predictions': array([0.04956755], dtype=float32)}
# {'predictions': array([1.1465281], dtype=float32)}
# {'predictions': array([0.20505434], dtype=float32)}
# {'predictions': array([-0.0190225], dtype=float32)}
# {'predictions': array([-0.26212382], dtype=float32)}
# {'predictions': array([0.06302074], dtype=float32)}
# {'predictions': array([0.54468393], dtype=float32)}
# {'predictions': array([0.06583524], dtype=float32)}
# {'predictions': array([0.05461379], dtype=float32)}
# {'predictions': array([0.07752124], dtype=float32)}
# {'predictions': array([0.04466172], dtype=float32)}
# {'predictions': array([1.0972613], dtype=float32)}
# {'predictions': array([1.0071495], dtype=float32)}
# {'predictions': array([0.84132355], dtype=float32)}
# {'predictions': array([0.9165893], dtype=float32)}
# {'predictions': array([0.8129452], dtype=float32)}
# {'predictions': array([0.7836707], dtype=float32)}
# {'predictions': array([0.803411], dtype=float32)}
# {'predictions': array([0.81665397], dtype=float32)}
# {'predictions': array([-0.06561867], dtype=float32)}
# {'predictions': array([-0.03017128], dtype=float32)}
# {'predictions': array([0.979366], dtype=float32)}
# {'predictions': array([0.92914295], dtype=float32)}
# {'predictions': array([0.15121004], dtype=float32)}
# {'predictions': array([0.541612], dtype=float32)}
# {'predictions': array([0.92094326], dtype=float32)}
# {'predictions': array([1.0110598], dtype=float32)}
# {'predictions': array([-0.0889254], dtype=float32)}
# {'predictions': array([0.84911823], dtype=float32)}
# {'predictions': array([0.7575624], dtype=float32)}
# {'predictions': array([1.3452182], dtype=float32)}
# {'predictions': array([0.56336194], dtype=float32)}
# {'predictions': array([1.1141225], dtype=float32)}
# {'predictions': array([0.75049055], dtype=float32)}
# {'predictions': array([-0.13253352], dtype=float32)}
# {'predictions': array([0.2672504], dtype=float32)}
# {'predictions': array([0.70298624], dtype=float32)}
# {'predictions': array([0.9356221], dtype=float32)}
# {'predictions': array([0.40080392], dtype=float32)}
# {'predictions': array([0.85193497], dtype=float32)}
# {'predictions': array([0.24386549], dtype=float32)}
# {'predictions': array([0.8759721], dtype=float32)}
# {'predictions': array([0.11477055], dtype=float32)}
# {'predictions': array([0.20654833], dtype=float32)}
# {'predictions': array([1.1268498], dtype=float32)}
# {'predictions': array([-0.35853714], dtype=float32)}
# {'predictions': array([0.05388679], dtype=float32)}
# {'predictions': array([-0.1922121], dtype=float32)}
# {'predictions': array([1.0622798], dtype=float32)}
# {'predictions': array([0.7661121], dtype=float32)}
# {'predictions': array([0.5341804], dtype=float32)}
# {'predictions': array([-0.00857381], dtype=float32)}
# {'predictions': array([0.7723236], dtype=float32)}
# {'predictions': array([0.87628955], dtype=float32)}
# {'predictions': array([0.20473945], dtype=float32)}
# {'predictions': array([-0.00249332], dtype=float32)}
# {'predictions': array([0.1525979], dtype=float32)}
# {'predictions': array([0.27134916], dtype=float32)}
# {'predictions': array([0.7627612], dtype=float32)}
# {'predictions': array([0.13566059], dtype=float32)}
# {'predictions': array([-0.08961666], dtype=float32)}
# {'predictions': array([0.62255406], dtype=float32)}
# {'predictions': array([0.6500524], dtype=float32)}
# {'predictions': array([1.1268018], dtype=float32)}
# {'predictions': array([-0.18585101], dtype=float32)}
# {'predictions': array([0.522349], dtype=float32)}
# {'predictions': array([1.0346847], dtype=float32)}
# {'predictions': array([0.76862216], dtype=float32)}
# {'predictions': array([0.41475806], dtype=float32)}
# {'predictions': array([-0.10283635], dtype=float32)}
# {'predictions': array([0.73049855], dtype=float32)}
# {'predictions': array([-0.0383885], dtype=float32)}
# {'predictions': array([1.1280276], dtype=float32)}
# {'predictions': array([1.1759061], dtype=float32)}
# {'predictions': array([0.29592016], dtype=float32)}
# {'predictions': array([-0.02354214], dtype=float32)}
# {'predictions': array([-0.15019655], dtype=float32)}
# {'predictions': array([0.2871809], dtype=float32)}
# {'predictions': array([0.890343], dtype=float32)}
# {'predictions': array([0.26900116], dtype=float32)}
# ...
# {'predictions': array([0.87736046], dtype=float32)}
# {'predictions': array([0.5497532], dtype=float32)}
# {'predictions': array([0.05439004], dtype=float32)}
# {'predictions': array([0.81663406], dtype=float32)}
# {'predictions': array([0.5820171], dtype=float32)}
# {'predictions': array([0.6613154], dtype=float32)}
# {'predictions': array([1.047269], dtype=float32)}
# {'predictions': array([0.7362506], dtype=float32)}
# {'predictions': array([0.90833837], dtype=float32)}
# {'predictions': array([0.24460545], dtype=float32)}
# {'predictions': array([0.7490213], dtype=float32)}
# {'predictions': array([0.81754565], dtype=float32)}
# {'predictions': array([0.25797352], dtype=float32)}
# {'predictions': array([0.8803961], dtype=float32)}
# {'predictions': array([0.2979261], dtype=float32)}
# {'predictions': array([0.04207506], dtype=float32)}
# {'predictions': array([0.03997817], dtype=float32)}
# {'predictions': array([0.1405896], dtype=float32)}
# {'predictions': array([0.5483749], dtype=float32)}
# {'predictions': array([1.1344794], dtype=float32)}
# {'predictions': array([0.19298643], dtype=float32)}
# {'predictions': array([-0.4624583], dtype=float32)}
# {'predictions': array([0.331251], dtype=float32)}
# {'predictions': array([0.5215066], dtype=float32)}
# {'predictions': array([1.0228367], dtype=float32)}
# {'predictions': array([0.18083525], dtype=float32)}
# {'predictions': array([0.6600995], dtype=float32)}
# {'predictions': array([0.17186356], dtype=float32)}
# {'predictions': array([0.46941653], dtype=float32)}
# {'predictions': array([0.5805231], dtype=float32)}
# {'predictions': array([0.7285167], dtype=float32)}
# {'predictions': array([0.6149566], dtype=float32)}
# {'predictions': array([0.01567321], dtype=float32)}
# {'predictions': array([0.8040805], dtype=float32)}
# {'predictions': array([0.21710694], dtype=float32)}
# {'predictions': array([0.27528134], dtype=float32)}
# {'predictions': array([-0.05933658], dtype=float32)}
# {'predictions': array([0.49320072], dtype=float32)}
# {'predictions': array([0.09775558], dtype=float32)}
# {'predictions': array([0.04377603], dtype=float32)}
# {'predictions': array([0.1098498], dtype=float32)}
# {'predictions': array([0.5242032], dtype=float32)}
# {'predictions': array([0.05822416], dtype=float32)}
# {'predictions': array([-0.03738431], dtype=float32)}
# {'predictions': array([0.09675997], dtype=float32)}
# {'predictions': array([0.49961996], dtype=float32)}
# {'predictions': array([-0.24761143], dtype=float32)}
# {'predictions': array([0.08137786], dtype=float32)}
# {'predictions': array([1.0197042], dtype=float32)}
# {'predictions': array([0.72431254], dtype=float32)}
# {'predictions': array([0.9040662], dtype=float32)}
# {'predictions': array([0.03080242], dtype=float32)}
# {'predictions': array([0.4868038], dtype=float32)}
# {'predictions': array([-0.29156974], dtype=float32)}
# {'predictions': array([0.441506], dtype=float32)}
# {'predictions': array([0.40068904], dtype=float32)}
# {'predictions': array([0.2992107], dtype=float32)}
# {'predictions': array([0.455173], dtype=float32)}
# {'predictions': array([0.18123251], dtype=float32)}
# {'predictions': array([0.6791993], dtype=float32)}
# {'predictions': array([0.7060354], dtype=float32)}
# {'predictions': array([0.10963713], dtype=float32)}
# {'predictions': array([0.9388613], dtype=float32)}
# {'predictions': array([0.86140084], dtype=float32)}
# {'predictions': array([0.06265829], dtype=float32)}
# {'predictions': array([1.0255015], dtype=float32)}
# {'predictions': array([1.0324863], dtype=float32)}
# {'predictions': array([0.44264534], dtype=float32)}
# {'predictions': array([0.5905254], dtype=float32)}
# {'predictions': array([0.05978819], dtype=float32)}
# {'predictions': array([0.8615322], dtype=float32)}
# {'predictions': array([-0.26773956], dtype=float32)}
# {'predictions': array([0.88711226], dtype=float32)}
# {'predictions': array([0.29624042], dtype=float32)}
# {'predictions': array([0.33214533], dtype=float32)}
# {'predictions': array([-0.07561371], dtype=float32)}
# {'predictions': array([1.009945], dtype=float32)}
# {'predictions': array([1.4278859], dtype=float32)}
# {'predictions': array([0.2267999], dtype=float32)}
# {'predictions': array([0.15914983], dtype=float32)}
# {'predictions': array([0.80690163], dtype=float32)}
# {'predictions': array([-0.22100493], dtype=float32)}
# {'predictions': array([0.28029975], dtype=float32)}
# {'predictions': array([0.49839953], dtype=float32)}
# {'predictions': array([0.2595888], dtype=float32)}
# {'predictions': array([0.68175244], dtype=float32)}
# {'predictions': array([0.21051031], dtype=float32)}
# {'predictions': array([-0.46430013], dtype=float32)}
# {'predictions': array([0.6314497], dtype=float32)}
# {'predictions': array([-0.07000337], dtype=float32)}
# {'predictions': array([-0.52081954], dtype=float32)}
# {'predictions': array([0.0840603], dtype=float32)}
# {'predictions': array([-0.04346202], dtype=float32)}
# {'predictions': array([0.4484791], dtype=float32)}
# {'predictions': array([0.98075914], dtype=float32)}
# {'predictions': array([-0.15841427], dtype=float32)}
# {'predictions': array([0.19700855], dtype=float32)}
# {'predictions': array([0.49093714], dtype=float32)}
# {'predictions': array([0.98846745], dtype=float32)}
# {'predictions': array([-0.12635282], dtype=float32)}
# {'predictions': array([0.44165602], dtype=float32)}
# {'predictions': array([-0.07067629], dtype=float32)}
# {'predictions': array([1.0040631], dtype=float32)}
# {'predictions': array([0.73808223], dtype=float32)}
# {'predictions': array([1.1193137], dtype=float32)}
# {'predictions': array([0.5547931], dtype=float32)}
# {'predictions': array([-0.05320651], dtype=float32)}
# {'predictions': array([0.6582252], dtype=float32)}
# {'predictions': array([-0.33165774], dtype=float32)}
# {'predictions': array([0.22829226], dtype=float32)}
# {'predictions': array([0.69080174], dtype=float32)}
# {'predictions': array([0.9921954], dtype=float32)}
# {'predictions': array([-0.10354581], dtype=float32)}
# {'predictions': array([0.16942775], dtype=float32)}
# {'predictions': array([1.066034], dtype=float32)}
# {'predictions': array([0.9545952], dtype=float32)}
# {'predictions': array([1.1060065], dtype=float32)}
# {'predictions': array([0.16548327], dtype=float32)}
# {'predictions': array([0.96665055], dtype=float32)}
# {'predictions': array([-0.16703403], dtype=float32)}
# {'predictions': array([0.70682967], dtype=float32)}
# {'predictions': array([0.26842332], dtype=float32)}
# {'predictions': array([0.82098347], dtype=float32)}
# {'predictions': array([0.22416744], dtype=float32)}
# {'predictions': array([0.43857712], dtype=float32)}
# {'predictions': array([-0.31561074], dtype=float32)}
# {'predictions': array([0.35545796], dtype=float32)}
# {'predictions': array([1.1290576], dtype=float32)}
# {'predictions': array([1.0415959], dtype=float32)}
# {'predictions': array([0.13791591], dtype=float32)}
# {'predictions': array([0.5774931], dtype=float32)}
# {'predictions': array([-0.623423], dtype=float32)}
# {'predictions': array([0.08783078], dtype=float32)}
# {'predictions': array([0.7341347], dtype=float32)}
# {'predictions': array([0.37964723], dtype=float32)}
# {'predictions': array([0.6176731], dtype=float32)}
# {'predictions': array([0.55323553], dtype=float32)}
# {'predictions': array([0.07927144], dtype=float32)}
# {'predictions': array([-0.15499523], dtype=float32)}
# {'predictions': array([0.20226035], dtype=float32)}
# {'predictions': array([0.34419432], dtype=float32)}
# {'predictions': array([0.23287669], dtype=float32)}
# {'predictions': array([0.86177814], dtype=float32)}
# {'predictions': array([-0.02851731], dtype=float32)}
# {'predictions': array([0.1133038], dtype=float32)}
# {'predictions': array([-0.01953203], dtype=float32)}
# {'predictions': array([0.79863], dtype=float32)}
# {'predictions': array([0.26064646], dtype=float32)}
# {'predictions': array([0.7207416], dtype=float32)}
# {'predictions': array([1.0421352], dtype=float32)}
# {'predictions': array([-0.1746372], dtype=float32)}
# {'predictions': array([0.02250984], dtype=float32)}
# {'predictions': array([-0.01951648], dtype=float32)}
# {'predictions': array([1.4916894], dtype=float32)}
# {'predictions': array([-0.211997], dtype=float32)}
# {'predictions': array([0.06497254], dtype=float32)}
# {'predictions': array([-0.247583], dtype=float32)}
# {'predictions': array([0.41157135], dtype=float32)}
# {'predictions': array([0.32147834], dtype=float32)}
# {'predictions': array([0.79084045], dtype=float32)}
# {'predictions': array([0.15852988], dtype=float32)}
# {'predictions': array([-0.42333353], dtype=float32)}
# {'predictions': array([0.10745726], dtype=float32)}
# {'predictions': array([0.21845847], dtype=float32)}
# {'predictions': array([0.9976116], dtype=float32)}
# {'predictions': array([0.08469211], dtype=float32)}
# {'predictions': array([0.91222334], dtype=float32)}
# {'predictions': array([0.10879985], dtype=float32)}
# {'predictions': array([0.30491164], dtype=float32)}
# {'predictions': array([0.63859665], dtype=float32)}
# {'predictions': array([0.874912], dtype=float32)}
# {'predictions': array([1.2908517], dtype=float32)}
# {'predictions': array([0.4871907], dtype=float32)}
# {'predictions': array([0.5171168], dtype=float32)}
# {'predictions': array([0.4584412], dtype=float32)}
# {'predictions': array([0.9626638], dtype=float32)}
# {'predictions': array([1.6760921], dtype=float32)}
# {'predictions': array([0.03921773], dtype=float32)}
# {'predictions': array([0.12124263], dtype=float32)}
# {'predictions': array([0.20653343], dtype=float32)}
# {'predictions': array([0.97844464], dtype=float32)}
# {'predictions': array([0.13563555], dtype=float32)}
# {'predictions': array([0.14708716], dtype=float32)}
# {'predictions': array([0.7468594], dtype=float32)}
# {'predictions': array([0.851104], dtype=float32)}
# {'predictions': array([0.51484436], dtype=float32)}
# {'predictions': array([-0.18273908], dtype=float32)}
# {'predictions': array([0.5494222], dtype=float32)}
# {'predictions': array([0.03033272], dtype=float32)}
# {'predictions': array([0.80147636], dtype=float32)}
# {'predictions': array([-0.19877061], dtype=float32)}
# {'predictions': array([-0.11372574], dtype=float32)}
# {'predictions': array([0.15287206], dtype=float32)}
# {'predictions': array([0.13384742], dtype=float32)}
# {'predictions': array([0.7107156], dtype=float32)}
# {'predictions': array([-0.3512162], dtype=float32)}
# {'predictions': array([0.3057459], dtype=float32)}
# {'predictions': array([0.96285594], dtype=float32)}
# {'predictions': array([0.09508806], dtype=float32)}
# {'predictions': array([0.7241185], dtype=float32)}
# {'predictions': array([1.0158947], dtype=float32)}
# {'predictions': array([-0.14553162], dtype=float32)}
# {'predictions': array([0.96096104], dtype=float32)}
# {'predictions': array([-0.63601303], dtype=float32)}
# {'predictions': array([0.07379778], dtype=float32)}
# {'predictions': array([0.7282375], dtype=float32)}
# {'predictions': array([0.5073939], dtype=float32)}
# {'predictions': array([0.84586036], dtype=float32)}
# {'predictions': array([0.50397104], dtype=float32)}
# {'predictions': array([-0.20818645], dtype=float32)}
# {'predictions': array([0.6320581], dtype=float32)}
# {'predictions': array([1.2318926], dtype=float32)}
# {'predictions': array([0.99715006], dtype=float32)}
# {'predictions': array([-0.56011367], dtype=float32)}
# {'predictions': array([0.9013932], dtype=float32)}
# {'predictions': array([-0.01468954], dtype=float32)}
# {'predictions': array([-0.10633319], dtype=float32)}
# {'predictions': array([0.20352936], dtype=float32)}
# {'predictions': array([0.9500662], dtype=float32)}
# {'predictions': array([0.54388505], dtype=float32)}
# {'predictions': array([0.9023148], dtype=float32)}
# {'predictions': array([0.9120426], dtype=float32)}
# {'predictions': array([0.19496965], dtype=float32)}
# {'predictions': array([0.5694679], dtype=float32)}
# {'predictions': array([-0.1193564], dtype=float32)}
# {'predictions': array([0.18710202], dtype=float32)}
# {'predictions': array([0.4826189], dtype=float32)}
# {'predictions': array([0.15089974], dtype=float32)}
# {'predictions': array([0.4082375], dtype=float32)}
# {'predictions': array([0.3929715], dtype=float32)}
# {'predictions': array([-0.05067336], dtype=float32)}
# {'predictions': array([0.6102525], dtype=float32)}
# {'predictions': array([0.19293311], dtype=float32)}
# {'predictions': array([-0.22399226], dtype=float32)}
# {'predictions': array([0.4870777], dtype=float32)}
# {'predictions': array([0.45331678], dtype=float32)}
# {'predictions': array([0.9045826], dtype=float32)}
# {'predictions': array([-0.3236176], dtype=float32)}
# {'predictions': array([0.1085762], dtype=float32)}
# {'predictions': array([0.89410126], dtype=float32)}
# {'predictions': array([0.00818574], dtype=float32)}
# {'predictions': array([0.7187276], dtype=float32)}
# {'predictions': array([0.6793327], dtype=float32)}
# {'predictions': array([1.0312014], dtype=float32)}
# {'predictions': array([-0.17475405], dtype=float32)}
# {'predictions': array([-0.11330006], dtype=float32)}
# {'predictions': array([-0.14468595], dtype=float32)}
# {'predictions': array([1.0871419], dtype=float32)}
# {'predictions': array([0.18269742], dtype=float32)}
# {'predictions': array([-0.15312192], dtype=float32)}
# {'predictions': array([0.22222331], dtype=float32)}
# {'predictions': array([-0.19054618], dtype=float32)}
# {'predictions': array([0.07183587], dtype=float32)}
# {'predictions': array([-0.04032985], dtype=float32)}
# {'predictions': array([-0.13019726], dtype=float32)}
# {'predictions': array([0.95662796], dtype=float32)}
# {'predictions': array([0.8028831], dtype=float32)}
# {'predictions': array([-0.79160166], dtype=float32)}
# {'predictions': array([0.06542192], dtype=float32)}
# {'predictions': array([0.75179493], dtype=float32)}
# {'predictions': array([0.3059229], dtype=float32)}
# {'predictions': array([-0.38833442], dtype=float32)}
# {'predictions': array([-0.27176228], dtype=float32)}
# {'predictions': array([0.31620377], dtype=float32)}
# {'predictions': array([0.05856834], dtype=float32)}
# {'predictions': array([0.2569941], dtype=float32)}
# {'predictions': array([-0.19024056], dtype=float32)}
# {'predictions': array([0.7234458], dtype=float32)}
# {'predictions': array([0.88146544], dtype=float32)}
# {'predictions': array([0.05846324], dtype=float32)}
# {'predictions': array([0.43640703], dtype=float32)}
# {'predictions': array([1.1050338], dtype=float32)}
# {'predictions': array([1.1867243], dtype=float32)}
# {'predictions': array([1.0744581], dtype=float32)}
# {'predictions': array([0.94520015], dtype=float32)}
# {'predictions': array([1.3286324], dtype=float32)}
# {'predictions': array([1.0298098], dtype=float32)}
# {'predictions': array([1.0508742], dtype=float32)}
# {'predictions': array([0.09635832], dtype=float32)}
# {'predictions': array([0.7400836], dtype=float32)}
# {'predictions': array([0.75595295], dtype=float32)}
# {'predictions': array([1.2635138], dtype=float32)}
# {'predictions': array([-0.1494435], dtype=float32)}
# {'predictions': array([0.9563457], dtype=float32)}
# {'predictions': array([0.18964332], dtype=float32)}
# {'predictions': array([0.20720917], dtype=float32)}
# {'predictions': array([1.1022669], dtype=float32)}
# {'predictions': array([0.26128525], dtype=float32)}
# {'predictions': array([1.0029868], dtype=float32)}
# {'predictions': array([0.442444], dtype=float32)}
# {'predictions': array([1.00093], dtype=float32)}
# {'predictions': array([-0.42889595], dtype=float32)}
# {'predictions': array([0.01761044], dtype=float32)}
# {'predictions': array([0.43092468], dtype=float32)}
# {'predictions': array([1.253719], dtype=float32)}
# {'predictions': array([-0.13071322], dtype=float32)}
# {'predictions': array([0.71887803], dtype=float32)}
# {'predictions': array([-0.3653699], dtype=float32)}
# {'predictions': array([0.643149], dtype=float32)}
# {'predictions': array([-0.05299673], dtype=float32)}
# {'predictions': array([0.55507267], dtype=float32)}
# {'predictions': array([0.14084846], dtype=float32)}
# {'predictions': array([0.6445541], dtype=float32)}
# {'predictions': array([1.0503261], dtype=float32)}
# {'predictions': array([0.27707496], dtype=float32)}
# {'predictions': array([0.01946151], dtype=float32)}
# {'predictions': array([0.5197759], dtype=float32)}
# {'predictions': array([0.7408646], dtype=float32)}
# {'predictions': array([0.3661457], dtype=float32)}

# %%
X_test

dfxtest = pd.DataFrame(X_test)
dfxtest.to_csv("xtest.csv")
